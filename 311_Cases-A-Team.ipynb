# %% [markdown]
# # Goup 2 : SF 311 Request Analysis
# by Paul Pineda,  James Ye,  Tanvir Khan, Travis Le
#
# ## Project Description:
#
# The 311 San Francsico platform serves as a tool to accept, process, and address various requests/complains from the community, such as requests for city street cleaning, graffiti, etc. In this project we use the 311-call data from the City of San Francisco to determine what are the major concerns of residents of San Francsico, what zip codes have the most 311 requests, what source was used the most to submit request, if the month or day of the week affect the number of request. and determine if there is any relation between the number of 311 calls per population, and income bracket.

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states
from pprint import pprint

# %%
# load data downloaded from SF311 database
cases_311_df = pd.read_csv("311_Cases.csv", low_memory=False)
cases_311_df
# Out:
#            CaseID                  Opened                  Closed  \
# 0          929675  07/29/2011 09:16:17 AM  11/16/2009 09:25:00 AM
# 1          572452  12/31/2009 05:42:50 PM  12/31/2009 07:16:33 PM
# 2          572435  12/31/2009 04:56:54 PM  12/31/2009 06:16:31 PM
# 3          572432  12/31/2009 04:49:38 PM  12/31/2009 06:16:30 PM
# 4          572429  12/31/2009 04:45:22 PM  12/31/2009 07:16:32 PM
# ...           ...                     ...                     ...
# 4139964  11426865  09/17/2019 09:34:23 AM  09/17/2019 12:38:39 PM
# 4139965  11420535  09/16/2019 03:31:00 AM  09/16/2019 03:49:42 AM
# 4139966  11426701  09/17/2019 09:11:00 AM  09/19/2019 07:14:00 AM
# 4139967  11423878  09/16/2019 02:53:00 PM  09/16/2019 07:10:29 PM
# 4139968  11416878  09/14/2019 06:45:36 PM  09/14/2019 06:45:38 PM
#
#                         Updated  Status  \
# 0        11/16/2009 09:25:00 AM  Closed
# 1        12/31/2009 07:16:33 PM  Closed
# 2        12/31/2009 06:16:31 PM  Closed
# 3        12/31/2009 06:16:30 PM  Closed
# 4        12/31/2009 07:16:32 PM  Closed
# ...                         ...     ...
# 4139964  09/17/2019 12:38:39 PM  Closed
# 4139965  09/16/2019 03:49:42 AM  Closed
# 4139966  09/19/2019 07:14:00 AM  Closed
# 4139967  09/16/2019 07:10:29 PM  Closed
# 4139968  09/14/2019 06:45:38 PM  Closed
#
#                                               Status Notes  \
# 0                                   Case Resolved - Closed
# 1                           See Notes tab for more details
# 2                           See Notes tab for more details
# 3                           See Notes tab for more details
# 4                           See Notes tab for more details
# ...                                                    ...
# 4139964                  Case Resolved - Pickup completed.
# 4139965                                      Case Resolved
# 4139966                            Case Resolved - 9-18-19
# 4139967                  Case Resolved - Pickup completed.
# 4139968  Comment Noted - The report has been logged and...
#
#                        Responsible Agency                      Category  \
# 0                           DPW BSM Queue            Litter Receptacles
# 1                           DPW Ops Queue  Street and Sidewalk Cleaning
# 2                           DPW Ops Queue  Street and Sidewalk Cleaning
# 3                           DPW Ops Queue                  Sewer Issues
# 4                           DPW Ops Queue  Street and Sidewalk Cleaning
# ...                                   ...                           ...
# 4139964                Recology_Abandoned  Street and Sidewalk Cleaning
# 4139965                     DPW Ops Queue  Street and Sidewalk Cleaning
# 4139966      DPT Paint Shop Transit Queue                      Graffiti
# 4139967                Recology_Abandoned  Street and Sidewalk Cleaning
# 4139968  Parking Enforcement Review Queue           Parking Enforcement
#
#                                              Request Type  \
# 0                                      Cans_Left_Out_24x7
# 1                 Overflowing_City_Receptacle_or_Dumpster
# 2                                             Bulky Items
# 3                                          Sewage_Back_Up
# 4                                        General Cleaning
# ...                                                   ...
# 4139964                                       Bulky Items
# 4139965                                  General Cleaning
# 4139966  Graffiti on Other_enter_additional_details_below
# 4139967                                       Bulky Items
# 4139968                             Blocking_Bicycle_Lane
#
#                                           Request Details  ...  \
# 0                                      Cans_Left_Out_24x7  ...
# 1                 Overflowing_City_Receptacle_or_Dumpster  ...
# 2                                             Electronics  ...
# 3                                     Outofsewervent4inch  ...
# 4                                     Other Loose Garbage  ...
# ...                                                   ...  ...
# 4139964                             Boxed or Bagged Items  ...
# 4139965                               Other Loose Garbage  ...
# 4139966  Other_enter_additional_details_below - Offensive  ...
# 4139967                                         Furniture  ...
# 4139968                               Parking Enforcement  ...
#
#         DELETE - HSOC Zones Fix It Zones as of 2018-02-07  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
# ...                     ...                           ...
# 4139964                 NaN                           NaN
# 4139965                 NaN                           NaN
# 4139966                 NaN                           NaN
# 4139967                 NaN                           NaN
# 4139968                 NaN                           NaN
#
#          CBD, BID and GBD Boundaries as of 2017  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 4139964                                     NaN
# 4139965                                     NaN
# 4139966                                     NaN
# 4139967                                     NaN
# 4139968                                     NaN
#
#         Central Market/Tenderloin Boundary Areas of Vulnerability, 2016  \
# 0                                      NaN                          2.0
# 1                                      NaN                          2.0
# 2                                      NaN                          2.0
# 3                                      NaN                          2.0
# 4                                      NaN                          2.0
# ...                                    ...                          ...
# 4139964                                NaN                          2.0
# 4139965                                NaN                          1.0
# 4139966                                NaN                          2.0
# 4139967                                NaN                          2.0
# 4139968                                NaN                          1.0
#
#          Central Market/Tenderloin Boundary Polygon - Updated  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 4139964                                                NaN
# 4139965                                                NaN
# 4139966                                                NaN
# 4139967                                                NaN
# 4139968                                                NaN
#
#          HSOC Zones as of 2018-06-05 OWED Public Spaces  \
# 0                                NaN                NaN
# 1                                NaN                NaN
# 2                                NaN                NaN
# 3                                NaN                NaN
# 4                                NaN                NaN
# ...                              ...                ...
# 4139964                          NaN                NaN
# 4139965                          NaN                NaN
# 4139966                          NaN                NaN
# 4139967                          NaN                NaN
# 4139968                          NaN                NaN
#
#         Parks Alliance CPSI (27+TL sites) Neighborhoods
# 0                                     NaN           8.0
# 1                                     NaN          91.0
# 2                                     NaN           8.0
# 3                                     NaN          90.0
# 4                                     NaN          91.0
# ...                                   ...           ...
# 4139964                               NaN          75.0
# 4139965                               NaN          31.0
# 4139966                               NaN          65.0
# 4139967                               NaN         107.0
# 4139968                               NaN         109.0
#
# [4139969 rows x 47 columns]

# %%
cases_311_df.count()
# Out:
# CaseID                                                  4139969
# Opened                                                  4139969
# Closed                                                  4060947
# Updated                                                 4139969
# Status                                                  4139969
# Status Notes                                            4112927
# Responsible Agency                                      4139969
# Category                                                4139969
# Request Type                                            4139969
# Request Details                                         4076250
# Address                                                 4139954
# Street                                                  3791606
# Supervisor District                                     3791626
# Neighborhood                                            3787636
# Police District                                         3786328
# Latitude                                                4139969
# Longitude                                               4139969
# Point                                                   4139969
# Source                                                  4139969
# Media URL                                               1226496
# SF Find Neighborhoods                                   3776736
# Current Police Districts                                3785396
# Current Supervisor Districts                            3789787
# Analysis Neighborhoods                                  3788948
# DELETE - Supervisor Districts                           3789787
# DELETE - Fire Prevention Districts                      3783383
# DELETE - Current Police Districts                       3786307
# DELETE - Zip Codes                                      3789099
# DELETE - Police Districts                               3786307
# DELETE - Neighborhoods                                  3788948
# DELETE - Neighborhoods_from_fyvs_ahh9                   3788948
# DELETE - 2017 Fix It Zones                               650026
# DELETE - SF Find Neighborhoods                          3776736
# Civic Center Harm Reduction Project Boundary             361887
# DELETE - Current Supervisor Districts                   3789787
# Fix It Zones as of 2017-11-06                            675733
# Invest In Neighborhoods (IIN) Areas                      163142
# DELETE - HSOC Zones                                      742892
# Fix It Zones as of 2018-02-07                            713509
# CBD, BID and GBD Boundaries as of 2017                   497135
# Central Market/Tenderloin Boundary                       296091
# Areas of Vulnerability, 2016                            3788948
# Central Market/Tenderloin Boundary Polygon - Updated     302099
# HSOC Zones as of 2018-06-05                              844789
# OWED Public Spaces                                        86264
# Parks Alliance CPSI (27+TL sites)                         19225
# Neighborhoods                                           3776736
# dtype: int64

# %%
# pick the columns we need
cases_311_slim_df = cases_311_df[["CaseID", "Opened", "Category", "Request Type","Neighborhood", 
                                  "Latitude", "Longitude", "Source", "Media URL"]]

cases_311_slim_df.head()
# Out:
#    CaseID                  Opened                      Category  \
# 0  929675  07/29/2011 09:16:17 AM            Litter Receptacles
# 1  572452  12/31/2009 05:42:50 PM  Street and Sidewalk Cleaning
# 2  572435  12/31/2009 04:56:54 PM  Street and Sidewalk Cleaning
# 3  572432  12/31/2009 04:49:38 PM                  Sewer Issues
# 4  572429  12/31/2009 04:45:22 PM  Street and Sidewalk Cleaning
#
#                               Request Type    Neighborhood   Latitude  \
# 0                       Cans_Left_Out_24x7  Outer Richmond  37.780376
# 1  Overflowing_City_Receptacle_or_Dumpster         Portola  37.727634
# 2                              Bulky Items  Outer Richmond  37.781925
# 3                           Sewage_Back_Up       Excelsior  37.719467
# 4                         General Cleaning         Portola  37.731480
#
#     Longitude Source Media URL
# 0 -122.487923  Phone       NaN
# 1 -122.403595  Phone       NaN
# 2 -122.487022  Phone       NaN
# 3 -122.428566  Phone       NaN
# 4 -122.410759  Phone       NaN

# %%
# create a new column with date in mm/dd/yyyy format
cases_311_slim_df['Opened Date'] = cases_311_slim_df["Opened"].str.slice(stop=10)
cases_311_slim_df
# Out:
# d:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            CaseID                  Opened                      Category  \
# 0          929675  07/29/2011 09:16:17 AM            Litter Receptacles
# 1          572452  12/31/2009 05:42:50 PM  Street and Sidewalk Cleaning
# 2          572435  12/31/2009 04:56:54 PM  Street and Sidewalk Cleaning
# 3          572432  12/31/2009 04:49:38 PM                  Sewer Issues
# 4          572429  12/31/2009 04:45:22 PM  Street and Sidewalk Cleaning
# ...           ...                     ...                           ...
# 4139964  11426865  09/17/2019 09:34:23 AM  Street and Sidewalk Cleaning
# 4139965  11420535  09/16/2019 03:31:00 AM  Street and Sidewalk Cleaning
# 4139966  11426701  09/17/2019 09:11:00 AM                      Graffiti
# 4139967  11423878  09/16/2019 02:53:00 PM  Street and Sidewalk Cleaning
# 4139968  11416878  09/14/2019 06:45:36 PM           Parking Enforcement
#
#                                              Request Type       Neighborhood  \
# 0                                      Cans_Left_Out_24x7     Outer Richmond
# 1                 Overflowing_City_Receptacle_or_Dumpster            Portola
# 2                                             Bulky Items     Outer Richmond
# 3                                          Sewage_Back_Up          Excelsior
# 4                                        General Cleaning            Portola
# ...                                                   ...                ...
# 4139964                                       Bulky Items  Visitacion Valley
# 4139965                                  General Cleaning        South Beach
# 4139966  Graffiti on Other_enter_additional_details_below     Merced Heights
# 4139967                                       Bulky Items       Russian Hill
# 4139968                             Blocking_Bicycle_Lane       Inner Sunset
#
#           Latitude   Longitude          Source  \
# 0        37.780376 -122.487923           Phone
# 1        37.727634 -122.403595           Phone
# 2        37.781925 -122.487022           Phone
# 3        37.719467 -122.428566           Phone
# 4        37.731480 -122.410759           Phone
# ...            ...         ...             ...
# 4139964  37.712605 -122.407304  Mobile/Open311
# 4139965  37.784486 -122.387571  Mobile/Open311
# 4139966  37.714264 -122.467081  Mobile/Open311
# 4139967  37.798416 -122.411209           Phone
# 4139968  37.761198 -122.463941  Mobile/Open311
#
#                                                  Media URL Opened Date
# 0                                                      NaN  07/29/2011
# 1                                                      NaN  12/31/2009
# 2                                                      NaN  12/31/2009
# 3                                                      NaN  12/31/2009
# 4                                                      NaN  12/31/2009
# ...                                                    ...         ...
# 4139964  http://mobile311.sfgov.org/reports/11426865/ph...  09/17/2019
# 4139965  http://mobile311.sfgov.org/reports/11420535/ph...  09/16/2019
# 4139966  http://mobile311.sfgov.org/reports/11426701/ph...  09/17/2019
# 4139967                                                NaN  09/16/2019
# 4139968  http://mobile311.sfgov.org/reports/11416878/ph...  09/14/2019
#
# [4139969 rows x 10 columns]

# %%
# create a new column with YYYY format
cases_311_slim_df['Opened Year'] = cases_311_slim_df['Opened Date'].str.slice(start =6)
cases_311_slim_df.head()
# Out:
# d:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    CaseID                  Opened                      Category  \
# 0  929675  07/29/2011 09:16:17 AM            Litter Receptacles
# 1  572452  12/31/2009 05:42:50 PM  Street and Sidewalk Cleaning
# 2  572435  12/31/2009 04:56:54 PM  Street and Sidewalk Cleaning
# 3  572432  12/31/2009 04:49:38 PM                  Sewer Issues
# 4  572429  12/31/2009 04:45:22 PM  Street and Sidewalk Cleaning
#
#                               Request Type    Neighborhood   Latitude  \
# 0                       Cans_Left_Out_24x7  Outer Richmond  37.780376
# 1  Overflowing_City_Receptacle_or_Dumpster         Portola  37.727634
# 2                              Bulky Items  Outer Richmond  37.781925
# 3                           Sewage_Back_Up       Excelsior  37.719467
# 4                         General Cleaning         Portola  37.731480
#
#     Longitude Source Media URL Opened Date Opened Year
# 0 -122.487923  Phone       NaN  07/29/2011        2011
# 1 -122.403595  Phone       NaN  12/31/2009        2009
# 2 -122.487022  Phone       NaN  12/31/2009        2009
# 3 -122.428566  Phone       NaN  12/31/2009        2009
# 4 -122.410759  Phone       NaN  12/31/2009        2009

# %%
# we only take data from 2017 and onward
cases_2017_df = cases_311_slim_df[cases_311_slim_df["Opened Year"].astype(int) > 2016]
cases_2017_df
# Out:
#            CaseID                  Opened                      Category  \
# 5        10395976  01/23/2019 01:34:53 PM                   Sign Repair
# 11       10328235  01/07/2019 07:18:11 PM              Tree Maintenance
# 12       10314300  01/04/2019 09:22:00 AM                Street Defects
# 13       10342330  01/10/2019 05:14:10 PM              Sidewalk or Curb
# 16       10560591  03/04/2019 12:24:00 PM              Sidewalk or Curb
# ...           ...                     ...                           ...
# 4139964  11426865  09/17/2019 09:34:23 AM  Street and Sidewalk Cleaning
# 4139965  11420535  09/16/2019 03:31:00 AM  Street and Sidewalk Cleaning
# 4139966  11426701  09/17/2019 09:11:00 AM                      Graffiti
# 4139967  11423878  09/16/2019 02:53:00 PM  Street and Sidewalk Cleaning
# 4139968  11416878  09/14/2019 06:45:36 PM           Parking Enforcement
#
#                                              Request Type       Neighborhood  \
# 5                                          Sign - Missing            Mission
# 11                                     Trees - Tree_Other       Outer Sunset
# 12                                        Pavement_Defect   Presidio Terrace
# 13                          Missing_Side_Sewer_Vent_Cover            Portola
# 16                               Curb_or_Curb_Ramp_Defect           Parkside
# ...                                                   ...                ...
# 4139964                                       Bulky Items  Visitacion Valley
# 4139965                                  General Cleaning        South Beach
# 4139966  Graffiti on Other_enter_additional_details_below     Merced Heights
# 4139967                                       Bulky Items       Russian Hill
# 4139968                             Blocking_Bicycle_Lane       Inner Sunset
#
#           Latitude   Longitude          Source  \
# 5        37.764091 -122.413002             Web
# 11       37.741627 -122.504688  Mobile/Open311
# 12       37.785984 -122.464783           Phone
# 13       37.716455 -122.400854  Mobile/Open311
# 16       37.746143 -122.487190           Phone
# ...            ...         ...             ...
# 4139964  37.712605 -122.407304  Mobile/Open311
# 4139965  37.784486 -122.387571  Mobile/Open311
# 4139966  37.714264 -122.467081  Mobile/Open311
# 4139967  37.798416 -122.411209           Phone
# 4139968  37.761198 -122.463941  Mobile/Open311
#
#                                                  Media URL Opened Date  \
# 5                                                      NaN  01/23/2019
# 11       http://mobile311.sfgov.org/reports/10328235/ph...  01/07/2019
# 12                                                     NaN  01/04/2019
# 13       http://mobile311.sfgov.org/reports/10342330/ph...  01/10/2019
# 16                                                     NaN  03/04/2019
# ...                                                    ...         ...
# 4139964  http://mobile311.sfgov.org/reports/11426865/ph...  09/17/2019
# 4139965  http://mobile311.sfgov.org/reports/11420535/ph...  09/16/2019
# 4139966  http://mobile311.sfgov.org/reports/11426701/ph...  09/17/2019
# 4139967                                                NaN  09/16/2019
# 4139968  http://mobile311.sfgov.org/reports/11416878/ph...  09/14/2019
#
#         Opened Year
# 5              2019
# 11             2019
# 12             2019
# 13             2019
# 16             2019
# ...             ...
# 4139964        2019
# 4139965        2019
# 4139966        2019
# 4139967        2019
# 4139968        2019
#
# [1951285 rows x 11 columns]

# %%
# getting ready for US Census api
from config import census_key
c = Census(census_key, year=2017)
c = Census(census_key)

# %%
# get US Census data by Zipcode
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# %%
# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate"]]

# Visualize
print(len(census_pd))
census_pd.tail(100)
# Out:
# 33120
#       Zipcode  Population   Median Age  Household Income  Per Capita Income  \
# 33020   99701     17608.0         32.2           58275.0            30330.0
# 33021   99702      3025.0         23.8           57464.0            26631.0
# 33022   99703      8415.0         22.9           54526.0            22746.0
# 33023   99704        30.0         20.7      -666666666.0            25570.0
# 33024   99705     22804.0         32.0           81045.0            34618.0
# ...       ...         ...          ...               ...                ...
# 33115   99923         0.0 -666666666.0      -666666666.0       -666666666.0
# 33116   99925       901.0         45.1           48646.0            24783.0
# 33117   99926      1684.0         32.8           57969.0            22927.0
# 33118   99927        59.0         49.8           17981.0            11959.0
# 33119   99929      2455.0         49.0           55742.0            29861.0
#
#        Poverty Count  Poverty Rate
# 33020         2481.0     14.090186
# 33021          115.0      3.801653
# 33022          448.0      5.323827
# 33023            0.0      0.000000
# 33024         1430.0      6.270830
# ...              ...           ...
# 33115            0.0           NaN
# 33116          210.0     23.307436
# 33117          224.0     13.301663
# 33118           49.0     83.050847
# 33119          276.0     11.242363
#
# [100 rows x 7 columns]

# %%
# load our excel file with San Francisco Neighborhood and Zipcode
neighborhoods_311_df = pd.read_excel("Neighborhoods_from_311data.xlsx")
neighborhoods_311_df
# Out:
#                 Neighborhood  Zipcode
# 0            Sherwood Forest    94127
# 1                 Tenderloin    94102
# 2               Civic Center    94102
# 3               Lower Haight    94102
# 4    Downtown / Union Square    94102
# ..                       ...      ...
# 112             McLaren Park    94134
# 113        Parnassus Heights    94143
# 114       Central Waterfront    94107
# 115              India Basin    94124
# 116            Forest Knolls    94116
#
# [117 rows x 2 columns]

# %%
# create summary_df which contains Census data with San Francisco zipcodes only
sf_df = pd.DataFrame()
sf_df["Zipcode"] = neighborhoods_311_df['Zipcode'].unique()
sf_df["Zipcode"] = sf_df["Zipcode"].astype(str)
summary_df = pd.merge(census_pd, sf_df, on = ['Zipcode'])
summary_df
# Out:
#    Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0    94102     30140.0        41.5           33552.0            43488.0
# 1    94103     26990.0        38.8           49052.0            55807.0
# 2    94104       436.0        51.3           48429.0            64267.0
# 3    94105      7675.0        37.6          199364.0           154723.0
# 4    94107     29920.0        35.9          143467.0            87735.0
# 5    94108     14856.0        42.8           55341.0            51359.0
# 6    94109     56587.0        36.9           79979.0            75460.0
# 7    94110     73737.0        36.6          109747.0            59660.0
# 8    94111      3356.0        46.1           99464.0            88610.0
# 9    94112     85373.0        41.4           82692.0            31905.0
# 10   94114     34561.0        40.4          143902.0           100685.0
# 11   94115     35751.0        36.0          103625.0            76686.0
# 12   94116     47708.0        42.9          101746.0            50165.0
# 13   94117     43610.0        33.6          132979.0            76623.0
# 14   94118     41417.0        37.4          102021.0            65842.0
# 15   94121     43638.0        43.7           87001.0            52321.0
# 16   94122     62516.0        39.5          102838.0            51615.0
# 17   94123     25461.0        34.4          134809.0           104926.0
# 18   94124     35492.0        35.3           55823.0            26061.0
# 19   94127     21093.0        45.0          151094.0            72905.0
# 20   94129      4019.0        29.4          190167.0            81974.0
# 21   94130      3129.0        25.8           52143.0            18012.0
# 22   94131     29056.0        41.5          119924.0            75754.0
# 23   94132     31155.0        33.2           72970.0            34028.0
# 24   94133     26942.0        43.0           66422.0            58461.0
# 25   94134     43074.0        40.2           71352.0            28790.0
#
#     Poverty Count  Poverty Rate
# 0          6957.0     23.082283
# 1          5870.0     21.748796
# 2            84.0     19.266055
# 3           733.0      9.550489
# 4          3391.0     11.333556
# 5          3178.0     21.392030
# 6          6718.0     11.871985
# 7          7321.0      9.928530
# 8           661.0     19.696067
# 9          7750.0      9.077811
# 10         2075.0      6.003877
# 11         4531.0     12.673771
# 12         4006.0      8.396915
# 13         3464.0      7.943132
# 14         3930.0      9.488857
# 15         3913.0      8.966955
# 16         5924.0      9.475974
# 17         1182.0      4.642394
# 18         7529.0     21.213231
# 19         1065.0      5.049068
# 20          122.0      3.035581
# 21         1561.0     49.888143
# 22         1676.0      5.768172
# 23         5124.0     16.446798
# 24         4314.0     16.012174
# 25         5048.0     11.719367

# %%
# add Zipcode to 311 Request data
cases_2017_df.head()
cases_2017_zipcode = pd.merge(cases_2017_df,neighborhoods_311_df, on="Neighborhood" )
cases_2017_zipcode
# Out:
#            CaseID                  Opened                        Category  \
# 0        10395976  01/23/2019 01:34:53 PM                     Sign Repair
# 1        11886797  01/01/2020 09:06:00 PM  General Request - PUBLIC WORKS
# 2        11089240  07/05/2019 03:12:37 PM                        Graffiti
# 3        11239390  08/07/2019 01:25:51 PM                        Graffiti
# 4        11886078  01/01/2020 03:27:00 PM    Street and Sidewalk Cleaning
# ...           ...                     ...                             ...
# 1877877  10492776  02/15/2019 09:42:20 AM                Tree Maintenance
# 1877878  11040396  06/24/2019 03:56:00 PM          General Request - TIDA
# 1877879  11015442  06/18/2019 08:45:00 PM                    Streetlights
# 1877880  10829747  05/07/2019 01:04:00 PM                  Street Defects
# 1877881  10772269  04/24/2019 12:46:00 PM                  Street Defects
#
#                           Request Type        Neighborhood   Latitude  \
# 0                       Sign - Missing             Mission  37.764091
# 1                  request_for_service             Mission  37.764840
# 2           Graffiti on Building_other             Mission  37.755848
# 3           Graffiti on Building_other             Mission  37.755703
# 4                     General Cleaning             Mission  37.769532
# ...                                ...                 ...        ...
# 1877877             Trees - Tree_Other  Yerba Buena Island  37.809266
# 1877878            request_for_service  Yerba Buena Island  37.813225
# 1877879  Streetlight - Light_Burnt_Out  Yerba Buena Island  37.809368
# 1877880                Pavement_Defect  Yerba Buena Island  37.813225
# 1877881                Pavement_Defect  Yerba Buena Island  37.813225
#
#           Longitude             Source  \
# 0       -122.413002                Web
# 1       -122.415038                Web
# 2       -122.414551  Integrated Agency
# 3       -122.416397  Integrated Agency
# 4       -122.415847     Mobile/Open311
# ...             ...                ...
# 1877877 -122.366807                Web
# 1877878 -122.371033              Phone
# 1877879 -122.370087              Phone
# 1877880 -122.371033              Phone
# 1877881 -122.371033              Phone
#
#                                                  Media URL Opened Date  \
# 0                                                      NaN  01/23/2019
# 1                                                      NaN  01/01/2020
# 2                                                      NaN  07/05/2019
# 3                                                      NaN  08/07/2019
# 4        http://mobile311.sfgov.org/reports/11886078/ph...  01/01/2020
# ...                                                    ...         ...
# 1877877  http://mobile311.sfgov.org/reports/10492776/ph...  02/15/2019
# 1877878                                                NaN  06/24/2019
# 1877879                                                NaN  06/18/2019
# 1877880                                                NaN  05/07/2019
# 1877881                                                NaN  04/24/2019
#
#         Opened Year  Zipcode
# 0              2019    94110
# 1              2020    94110
# 2              2019    94110
# 3              2019    94110
# 4              2020    94110
# ...             ...      ...
# 1877877        2019    94130
# 1877878        2019    94130
# 1877879        2019    94130
# 1877880        2019    94130
# 1877881        2019    94130
#
# [1877882 rows x 12 columns]

# %%
# merge 311 data(cases_2017_zipcode) with Census data (summary_df)
# save this final_df to a csv file for later use
summary_df['Zipcode'] = summary_df['Zipcode'].astype(int)
final_df = pd.merge(cases_2017_zipcode, summary_df, on="Zipcode")
final_df.to_csv("final_df.csv")
final_df
# Out:
#            CaseID                  Opened                        Category  \
# 0        10395976  01/23/2019 01:34:53 PM                     Sign Repair
# 1        11886797  01/01/2020 09:06:00 PM  General Request - PUBLIC WORKS
# 2        11089240  07/05/2019 03:12:37 PM                        Graffiti
# 3        11239390  08/07/2019 01:25:51 PM                        Graffiti
# 4        11886078  01/01/2020 03:27:00 PM    Street and Sidewalk Cleaning
# ...           ...                     ...                             ...
# 1873838  11445821  09/21/2019 08:53:04 AM                     Encampments
# 1873839  11451330  09/22/2019 06:16:00 PM                  Street Defects
# 1873840  11416625  09/14/2019 05:20:44 PM             Parking Enforcement
# 1873841  11444928  09/20/2019 07:55:37 PM                    Noise Report
# 1873842  11447775  09/21/2019 05:10:00 PM                     Sign Repair
#
#                        Request Type            Neighborhood   Latitude  \
# 0                    Sign - Missing                 Mission  37.764091
# 1               request_for_service                 Mission  37.764840
# 2        Graffiti on Building_other                 Mission  37.755848
# 3        Graffiti on Building_other                 Mission  37.755703
# 4                  General Cleaning                 Mission  37.769532
# ...                             ...                     ...        ...
# 1873838          Encampment Reports  Presidio National Park  37.806462
# 1873839             Pavement_Defect  Presidio National Park  37.804123
# 1873840       Blocking_Bicycle_Lane  Presidio National Park  37.801830
# 1873841                 Noise Issue  Presidio National Park  37.808779
# 1873842       Sign Repair - Missing  Presidio National Park  37.808099
#
#           Longitude             Source  \
# 0       -122.413002                Web
# 1       -122.415038                Web
# 2       -122.414551  Integrated Agency
# 3       -122.416397  Integrated Agency
# 4       -122.415847     Mobile/Open311
# ...             ...                ...
# 1873838 -122.450988     Mobile/Open311
# 1873839 -122.472125     Mobile/Open311
# 1873840 -122.456973     Mobile/Open311
# 1873841 -122.471963     Mobile/Open311
# 1873842 -122.470892     Mobile/Open311
#
#                                                  Media URL Opened Date  \
# 0                                                      NaN  01/23/2019
# 1                                                      NaN  01/01/2020
# 2                                                      NaN  07/05/2019
# 3                                                      NaN  08/07/2019
# 4        http://mobile311.sfgov.org/reports/11886078/ph...  01/01/2020
# ...                                                    ...         ...
# 1873838  http://mobile311.sfgov.org/reports/11445821/ph...  09/21/2019
# 1873839                                                NaN  09/22/2019
# 1873840  http://mobile311.sfgov.org/reports/11416625/ph...  09/14/2019
# 1873841                                                NaN  09/20/2019
# 1873842                                                NaN  09/21/2019
#
#         Opened Year  Zipcode  Population  Median Age  Household Income  \
# 0              2019    94110     73737.0        36.6          109747.0
# 1              2020    94110     73737.0        36.6          109747.0
# 2              2019    94110     73737.0        36.6          109747.0
# 3              2019    94110     73737.0        36.6          109747.0
# 4              2020    94110     73737.0        36.6          109747.0
# ...             ...      ...         ...         ...               ...
# 1873838        2019    94129      4019.0        29.4          190167.0
# 1873839        2019    94129      4019.0        29.4          190167.0
# 1873840        2019    94129      4019.0        29.4          190167.0
# 1873841        2019    94129      4019.0        29.4          190167.0
# 1873842        2019    94129      4019.0        29.4          190167.0
#
#          Per Capita Income  Poverty Count  Poverty Rate
# 0                  59660.0         7321.0      9.928530
# 1                  59660.0         7321.0      9.928530
# 2                  59660.0         7321.0      9.928530
# 3                  59660.0         7321.0      9.928530
# 4                  59660.0         7321.0      9.928530
# ...                    ...            ...           ...
# 1873838            81974.0          122.0      3.035581
# 1873839            81974.0          122.0      3.035581
# 1873840            81974.0          122.0      3.035581
# 1873841            81974.0          122.0      3.035581
# 1873842            81974.0          122.0      3.035581
#
# [1873843 rows x 18 columns]

# %% [markdown]
# # We will use the same final_df.csv generated in this notebook for our hypothesis analysis.
